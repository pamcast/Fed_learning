# %%
import os
import random
import numpy as np
import torch
from torchvision import datasets, transforms

# ---- CONFIG ----
ROOT = "/Users/ishabhansali/Downloads/resnet_project/cleaned"  # Adjust if your notebook is not in RESNET_PROJECT root
TRAIN_DIR = os.path.join(ROOT, "Training")
TEST_DIR = os.path.join(ROOT, "Testing")
NUM_CLIENTS = 4
LOCAL_TEST_FRAC = 0.2
SEED = 77

# ---- REPRODUCIBILITY ----
def set_seed(s=SEED):
    random.seed(s)
    np.random.seed(s)
    torch.manual_seed(s)
    torch.cuda.manual_seed_all(s)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
set_seed()

# ---- PATH CHECKS ----
if not os.path.exists(ROOT):
    raise FileNotFoundError(f"ROOT folder not found: {ROOT}")
if not os.path.exists(TRAIN_DIR):
    raise FileNotFoundError(f"Training directory not found: {TRAIN_DIR}")
if not os.path.exists(TEST_DIR):
    raise FileNotFoundError(f"Testing directory not found: {TEST_DIR}")

print("Training classes:", os.listdir(TRAIN_DIR))
print("Testing classes:", os.listdir(TEST_DIR))

# ---- TRANSFORM AND LOAD ----
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=transform)
test_dataset = datasets.ImageFolder(TEST_DIR, transform=transform)
print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

# ---- IID PARTITION ----
num_items = len(train_dataset)
client_lengths = [num_items // NUM_CLIENTS] * NUM_CLIENTS
client_lengths[0] += num_items - sum(client_lengths)  # Add remainder to first client

from torch.utils.data import random_split

client_subsets = random_split(train_dataset, client_lengths, generator=torch.Generator().manual_seed(SEED))
print("Client samples:", [len(subset) for subset in client_subsets])

# ---- TEST SPLIT FOR EACH CLIENT ----
client_data = []
for c in client_subsets:
    n_test = int(len(c) * LOCAL_TEST_FRAC)
    n_train = len(c) - n_test
    tr, te = random_split(c, [n_train, n_test], generator=torch.Generator().manual_seed(SEED))
    client_data.append((tr, te))
    print(f"Client train: {n_train}, test: {n_test}")

# ---- SAMPLE ACCESS ----
image, label = client_data[0][0][0]  # First sample from client 0 train set
print("First client, first train label:", label)
# Out:
# Training classes: ['pituitary', 'notumor', 'glioma', 'meningioma']
# Testing classes: ['pituitary', 'notumor', 'glioma', 'meningioma']
# Train samples: 5712, Test samples: 1311
# Client samples: [1428, 1428, 1428, 1428]
# Client train: 1143, test: 285
# Client train: 1143, test: 285
# Client train: 1143, test: 285
# Client train: 1143, test: 285
# First client, first train label: 0

# %%
# Get class names from the underlying ImageFolder
class_names = train_dataset.classes

# Count samples per class for each client
for idx, (client_train, _) in enumerate(client_data):
    # Extract all labels for this client's training subset
    labels = [client_train[i][1] for i in range(len(client_train))]
    # Count occurrences of each label
    counts = {class_name: labels.count(i) for i, class_name in enumerate(class_names)}
    print(f"Client {idx}:")
    for class_name in class_names:
        print(f"  {class_name}: {counts[class_name]} samples")
    print("-" * 30)
# Out:
# Client 0:
#   glioma: 243 samples
#   meningioma: 294 samples
#   notumor: 310 samples
#   pituitary: 296 samples
# ------------------------------
# Client 1:
#   glioma: 303 samples
#   meningioma: 242 samples
#   notumor: 309 samples
#   pituitary: 289 samples
# ------------------------------
# Client 2:
#   glioma: 259 samples
#   meningioma: 265 samples
#   notumor: 310 samples
#   pituitary: 309 samples
# ------------------------------
# Client 3:
#   glioma: 253 samples
#   meningioma: 260 samples
#   notumor: 344 samples
#   pituitary: 286 samples
# ------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ============================================================
#              1. Class Count per Client (Train Only)
# ============================================================
client_class_dist = []

for client_train, _ in client_data:  # only train split
    labels = [client_train[i][1] for i in range(len(client_train))]
    counts = [labels.count(i) for i in range(len(class_names))]
    client_class_dist.append(counts)

num_clients = len(client_class_dist)
num_classes = len(class_names)

# ----- Plot: stacked bar chart -----
fig, ax = plt.subplots(figsize=(12, 6))
x = np.arange(num_clients)
bottom = np.zeros(num_clients)

colors = plt.cm.Set3(np.linspace(0, 1, num_classes))

for class_idx in range(num_classes):
    values = [client_class_dist[c][class_idx] for c in range(num_clients)]
    ax.bar(x, values, bottom=bottom, width=0.55, 
           color=colors[class_idx], label=class_names[class_idx])
    bottom += np.array(values)

ax.set_xticks(x)
ax.set_xticklabels([f"Client {i}" for i in range(num_clients)])
ax.set_ylabel("Number of Samples")
ax.set_title("IID Class Distribution per Client (Train Set)")
ax.legend(title="Classes", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# ============================================================
#              2. Heatmap of Class Percentages
# ============================================================
heatmap_data = []
for counts in client_class_dist:
    total = sum(counts)
    row = [100 * c / total if total > 0 else 0 for c in counts]
    heatmap_data.append(row)
heatmap_data = np.array(heatmap_data)

plt.figure(figsize=(10, 6))
sns.heatmap(
    heatmap_data, annot=True, fmt=".1f", cmap="Blues", 
    xticklabels=class_names, 
    yticklabels=[f"Client {i}" for i in range(num_clients)],
    cbar_kws={'label': 'Percentage (%)'},
    vmin=0, vmax=100
)
plt.title("IID Train Set: Class Percentage Heatmap")
plt.xlabel("Classes")
plt.ylabel("Clients")
plt.tight_layout()
plt.show()

# ============================================================
#              3. Train/Test Counts per Client
# ============================================================
client_train_counts = []
client_test_counts = []

for train_subset, test_subset in client_data:
    train_labels = [train_subset[i][1] for i in range(len(train_subset))]
    test_labels  = [test_subset[i][1]  for i in range(len(test_subset))]
    
    train_counts = [train_labels.count(i) for i in range(num_classes)]
    test_counts  = [test_labels.count(i)  for i in range(num_classes)]
    
    client_train_counts.append(train_counts)
    client_test_counts.append(test_counts)

client_train_counts = np.array(client_train_counts)
client_test_counts = np.array(client_test_counts)

fig, axs = plt.subplots(1, num_clients, figsize=(6 * num_clients, 5), sharey=True)
x = np.arange(num_classes)
width = 0.35

for idx in range(num_clients):
    axs[idx].bar(x - width/2, client_train_counts[idx], width, label="Train", color='tab:blue')
    axs[idx].bar(x + width/2, client_test_counts[idx], width, label="Test",  color='tab:orange')
    
    axs[idx].set_xticks(x)
    axs[idx].set_xticklabels(class_names, rotation=15)
    axs[idx].set_title(f"Client {idx}")
    axs[idx].set_ylabel("Samples")
    axs[idx].legend()

plt.suptitle("IID Train/Test Class Distribution per Client")
plt.tight_layout(rect=[0,0,1,0.95])
plt.show()

# ============================================================
#              4. Client Dataset Sizes
# ============================================================
client_sizes = [sum(c) for c in client_class_dist]

plt.figure(figsize=(8,5))
bars = plt.bar(
    [f"Client {i}" for i in range(num_clients)],
    client_sizes, 
    color=plt.cm.Set2(np.linspace(0,1,num_clients)),
    edgecolor="black"
)
plt.ylabel("Number of Train Samples")
plt.title("IID Setup: Client Train Set Sizes")

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2.,
        height,
        f"{int(height)}",
        ha='center', va='bottom'
    )

plt.tight_layout()
plt.show()

# ============================================================
#              5. Global vs Client Distribution
# ============================================================
global_counts = np.sum(client_class_dist, axis=0)
global_total = np.sum(global_counts)
global_percent = [100 * c/global_total for c in global_counts]

fig, axes = plt.subplots(2, (num_clients+1)//2, figsize=(14,10))
axes = axes.flatten()

for idx in range(num_clients):
    client_total = sum(client_class_dist[idx])
    client_percent = [100*c/client_total for c in client_class_dist[idx]]

    x_pos = np.arange(num_classes)
    width = 0.35

    axes[idx].bar(x_pos - width/2, global_percent, width, label="Global", color='skyblue')
    axes[idx].bar(x_pos + width/2, client_percent, width, label=f"Client {idx}", color='coral')

    axes[idx].set_title(f"IID: Client {idx} vs Global")
    axes[idx].set_xticks(x_pos)
    axes[idx].set_xticklabels(class_names, rotation=45)
    axes[idx].set_ylabel("Percentage (%)")
    axes[idx].legend()

plt.tight_layout()
plt.show()

# ============================================================
#              6. Summary Statistics
# ============================================================
print("\n" + "="*50)
print("IID DATA DISTRIBUTION SUMMARY (Train)")
print("="*50)

for idx, counts in enumerate(client_class_dist):
    total = sum(counts)
    print(f"\nClient {idx}: {total} samples")
    for class_idx, class_name in enumerate(class_names):
        pct = 100 * counts[class_idx] / total
        print(f"  {class_name}: {counts[class_idx]} ({pct:.1f}%)")

print("\n" + "="*50)
print("Global Distribution (Train Set):")
print("="*50)
for class_idx, class_name in enumerate(class_names):
    pct = 100 * global_counts[class_idx] / global_total
    print(f"  {class_name}: {global_counts[class_idx]} ({pct:.1f}%)")
print("="*50)
# Out:
# ==================================================
# IID DATA DISTRIBUTION SUMMARY (Train)
# ==================================================
#
# Client 0: 1143 samples
#   glioma: 243 (21.3%)
#   meningioma: 294 (25.7%)
#   notumor: 310 (27.1%)
#   pituitary: 296 (25.9%)
#
# Client 1: 1143 samples
#   glioma: 303 (26.5%)
#   meningioma: 242 (21.2%)
#   notumor: 309 (27.0%)
#   pituitary: 289 (25.3%)
#
# Client 2: 1143 samples
#   glioma: 259 (22.7%)
#   meningioma: 265 (23.2%)
#   notumor: 310 (27.1%)
#   pituitary: 309 (27.0%)
#
# Client 3: 1143 samples
#   glioma: 253 (22.1%)
#   meningioma: 260 (22.7%)
#   notumor: 344 (30.1%)
#   pituitary: 286 (25.0%)
#
# ==================================================
# Global Distribution (Train Set):
# ==================================================
#   glioma: 1058 (23.1%)
#   meningioma: 1061 (23.2%)
#   notumor: 1273 (27.8%)
#   pituitary: 1180 (25.8%)
# ==================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_class_distribution_iid(client_subsets, class_names):
    num_clients = len(client_subsets)
    num_classes = len(class_names)

    # Count per-class samples for each client
    dist_matrix = np.zeros((num_clients, num_classes), dtype=int)

    for client_id, subset in enumerate(client_subsets):
        labels = [subset[i][1] for i in range(len(subset))]
        for cls in range(num_classes):
            dist_matrix[client_id, cls] = labels.count(cls)

    # ----------- Plot Bar Chart -----------
    x = np.arange(num_clients)
    width = 0.2   # width of each bar

    plt.figure(figsize=(10,5))

    for cls in range(num_classes):
        plt.bar(x + cls*width, dist_matrix[:, cls], width, label=class_names[cls])

    plt.xticks(x + width, [f"client_{i}" for i in range(num_clients)])
    plt.ylabel("Number of Images")
    plt.title("Class Distribution per Client (IID Partition)")
    plt.legend()
    plt.grid(axis='y', alpha=0.3)

    plt.show()

    return dist_matrix

# %%
class_distribution_iid = plot_class_distribution_iid(client_subsets, class_names)

# %%
import numpy as np
from scipy.spatial.distance import jensenshannon

# -----------------------------------------
# 1. Prepare class distributions per client
# -----------------------------------------
num_classes = len(train_dataset.classes)
num_clients = len(client_subsets)

client_distributions = []

for k in range(num_clients):
    subset = client_subsets[k]
    counts = np.zeros(num_classes)

    for i in range(len(subset)):
        class_idx = subset[i][1]
        counts[class_idx] += 1

    # Normalize to probabilities
    prob_vec = counts / counts.sum() if counts.sum() > 0 else counts
    client_distributions.append(prob_vec)

# -----------------------------------------
# 2. Compute global distribution
# -----------------------------------------
global_counts = np.zeros(num_classes)

for _, cls_idx in train_dataset.samples:
    global_counts[cls_idx] += 1

global_dist = global_counts / global_counts.sum()

print("Global Class Distribution:", global_dist)
print("Classes:", train_dataset.classes)

# -----------------------------------------
# 3. Compute JS Divergence per client
# -----------------------------------------
print("\n" + "="*70)
print("JENSEN-SHANNON DIVERGENCE (Client vs Global) — IID Setup")
print("="*70)
print("Range: 0 (identical) to 1 (completely different)\n")

js_values = []
for k, dist in enumerate(client_distributions):
    js = jensenshannon(global_dist, dist)
    js_values.append(js)
    print(f"Client {k}: JS Divergence = {js:.4f}")

print(f"\nAverage JS Divergence: {np.mean(js_values):.4f}")
# Out:
# Global Class Distribution: [0.23126751 0.23441877 0.27923669 0.25507703]
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
#
# ======================================================================
# JENSEN-SHANNON DIVERGENCE (Client vs Global) — IID Setup
# ======================================================================
# Range: 0 (identical) to 1 (completely different)
#
# Client 0: JS Divergence = 0.0258
# Client 1: JS Divergence = 0.0344
# Client 2: JS Divergence = 0.0078
# Client 3: JS Divergence = 0.0201
#
# Average JS Divergence: 0.0220

# %%
import numpy as np
from scipy.spatial.distance import jensenshannon
import matplotlib.pyplot as plt
import seaborn as sns

num_clients = len(client_subsets)
num_classes = len(train_dataset.classes)

# -----------------------------------------
# 1. Compute probability distribution per client
# -----------------------------------------
client_dists = []

for subset in client_subsets:
    counts = np.zeros(num_classes)
    
    labels = [subset[i][1] for i in range(len(subset))]
    for cls in labels:
        counts[cls] += 1

    prob = counts / counts.sum() if counts.sum() > 0 else counts
    client_dists.append(prob)

# -----------------------------------------
# 2. Compute pairwise JS matrix
# -----------------------------------------
pairwise_js = np.zeros((num_clients, num_clients))

for i in range(num_clients):
    for j in range(num_clients):
        pairwise_js[i, j] = jensenshannon(client_dists[i], client_dists[j])

# -----------------------------------------
# 3. Heatmap
# -----------------------------------------
plt.figure(figsize=(8, 7))
sns.heatmap(
    pairwise_js, annot=True, fmt=".4f", cmap="YlGnBu",
    xticklabels=[f"Client {i}" for i in range(num_clients)],
    yticklabels=[f"Client {i}" for i in range(num_clients)],
    cbar_kws={'label': 'JS Divergence'}
)
plt.title("Pairwise Jensen-Shannon Divergence — IID Setup", fontsize=14, fontweight="bold")
plt.xlabel("Clients")
plt.ylabel("Clients")
plt.tight_layout()
plt.show()

# %%
# ============================================================
#        FEDAVG (IID) — PRETRAINED RESNET18 + ITERATIONS
# ============================================================

import random
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torch.utils.data import DataLoader


# ============================================================
#                    DEVICE SETUP
# ============================================================
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
    print("🚀 Using Apple Silicon GPU (MPS)")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print("🚀 Using NVIDIA GPU (CUDA)")
else:
    DEVICE = torch.device("cpu")
    print("🖥 Using CPU")


# ============================================================
#                       CONFIG
# ============================================================
SEED_IID = 77
NUM_ROUNDS_IID = 200             # maximum
LOCAL_ITERATIONS = 10            # 🔥 new: iteration-based training
LR_IID = 3e-4
BATCH_SIZE_IID = 32

NUM_CLIENTS_IID = len(client_data)
NUM_CLASSES_IID = len(train_dataset.classes)

PATIENCE = 15                    # 🔥 early stopping patience


# Reproducibility
random.seed(SEED_IID)
np.random.seed(SEED_IID)
torch.manual_seed(SEED_IID)
torch.cuda.manual_seed_all(SEED_IID)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

crit_ce_iid = nn.CrossEntropyLoss()


# ============================================================
#     PRETRAINED RESNET18 WITH FREEZING STRATEGY (IID)
# ============================================================
def create_pretrained_resnet18_iid(num_classes: int) -> nn.Module:
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

    # Freeze early layers
    for p in model.conv1.parameters(): p.requires_grad = False
    for p in model.bn1.parameters(): p.requires_grad = False
    for p in model.layer1.parameters(): p.requires_grad = False
    for p in model.layer2.parameters(): p.requires_grad = False

    # Train deeper layers
    for p in model.layer3.parameters(): p.requires_grad = True
    for p in model.layer4.parameters(): p.requires_grad = True

    # Replace FC head
    in_f = model.fc.in_features
    model.fc = nn.Linear(in_f, num_classes)

    return model


# ============================================================
#                  ITERATION-BASED TRAINING
# ============================================================
def train_local_iterations(model, loader, device, optimizer, num_steps):
    """
    Instead of epochs, perform fixed number of SGD steps.
    Each round uses a NEW shuffled loader.
    """
    model.train()
    iterator = iter(loader)

    tot_loss, tot_corr, tot = 0.0, 0, 0

    for step in range(num_steps):
        try:
            x, y = next(iterator)
        except StopIteration:
            iterator = iter(loader)
            x, y = next(iterator)

        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        loss = crit_ce_iid(logits, y)
        loss.backward()
        optimizer.step()

        bs = x.size(0)
        tot_loss += loss.item() * bs
        tot_corr += (logits.argmax(1) == y).sum().item()
        tot += bs

    return {"loss": tot_loss / tot, "acc": tot_corr / tot}


@torch.no_grad()
def evaluate_iid(model, loader, device):
    model.eval()
    tot_loss, tot_corr, tot = 0.0, 0, 0

    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = crit_ce_iid(logits, y)

        bs = x.size(0)
        tot_loss += loss.item() * bs
        tot_corr += (logits.argmax(1) == y).sum().item()
        tot += bs

    return {"loss": tot_loss / tot, "acc": tot_corr / tot}


# ============================================================
#           CLIENT TRAIN + LOCAL TEST LOADERS (IID)
# ============================================================
client_train_loaders_iid = []
client_test_loaders_iid = []

for train_subset, test_subset in client_data:
    client_train_loaders_iid.append(
        DataLoader(train_subset, batch_size=BATCH_SIZE_IID, shuffle=True)
    )
    client_test_loaders_iid.append(
        DataLoader(test_subset, batch_size=BATCH_SIZE_IID, shuffle=False)
    )

holdout_loader_iid = DataLoader(test_dataset, batch_size=BATCH_SIZE_IID, shuffle=False)


# ============================================================
#          GLOBAL MODEL + METRICS + EARLY STOPPING
# ============================================================
global_model_iid = create_pretrained_resnet18_iid(NUM_CLASSES_IID).to(DEVICE)

best_acc_iid = -1.0
best_state_iid = None
no_improve_count = 0

metrics_history_fedavg_iid_pretrained = {
    "round": [],
    "holdout": [],
    "clients": {k: [] for k in range(NUM_CLIENTS_IID)},
}


# ============================================================
#                      FEDAVG LOOP (IID)
# ============================================================
for rnd in range(NUM_ROUNDS_IID):

    print(f"\n🔁 [IID] FedAvg Pretrained Round {rnd + 1}/{NUM_ROUNDS_IID}")

    local_states = []

    # ----- CLIENT TRAINING -----
    for k in range(NUM_CLIENTS_IID):

        local_model = copy.deepcopy(global_model_iid).to(DEVICE)

        optimizer = optim.Adam(
            (p for p in local_model.parameters() if p.requires_grad),
            lr=LR_IID,
        )

        # 🔥 iteration-based training
        train_metrics = train_local_iterations(
            local_model,
            client_train_loaders_iid[k],
            DEVICE,
            optimizer,
            LOCAL_ITERATIONS,
        )

        # Store model state for averaging
        local_states.append(
            {n: p.cpu() for n, p in local_model.state_dict().items()}
        )

        # Local evaluation
        client_metric = evaluate_iid(
            local_model, client_test_loaders_iid[k], DEVICE
        )
        metrics_history_fedavg_iid_pretrained["clients"][k].append(client_metric)

        print(
            f"  Client {k} | "
            f"Train Loss: {train_metrics['loss']:.4f}, "
            f"Train Acc: {train_metrics['acc']:.4f}, "
            f"Local Test Acc: {client_metric['acc']:.4f}"
        )

    # ----- FEDAVG AGGREGATION -----
    new_state = {}
    for key in global_model_iid.state_dict().keys():
        stacked = torch.stack([state[key] for state in local_states], dim=0)

        if stacked.dtype.is_floating_point:
            new_state[key] = stacked.mean(dim=0)
        else:
            new_state[key] = stacked[0]

    global_model_iid.load_state_dict(new_state)

    # ----- GLOBAL HOLDOUT EVAL -----
    holdout_metric = evaluate_iid(global_model_iid, holdout_loader_iid, DEVICE)

    metrics_history_fedavg_iid_pretrained["round"].append(rnd + 1)
    metrics_history_fedavg_iid_pretrained["holdout"].append(holdout_metric)

    print(
        f"🌍 [IID] Global Holdout | "
        f"Acc: {holdout_metric['acc']:.4f}, "
        f"Loss: {holdout_metric['loss']:.4f}"
    )

    # ----- EARLY STOPPING -----
    if holdout_metric["acc"] > best_acc_iid:
        best_acc_iid = holdout_metric["acc"]
        best_state_iid = copy.deepcopy(global_model_iid.state_dict())
        no_improve_count = 0
        print(f"💾 [IID] New BEST Model Saved! Acc = {best_acc_iid:.4f}")
    else:
        no_improve_count += 1
        print(f"⏳ No improvement for {no_improve_count}/{PATIENCE} rounds.")

    if no_improve_count >= PATIENCE:
        print("\n🛑 Early stopping triggered! Training converged.")
        break


# ============================================================
#                     SAVE OUTPUTS (IID)
# ============================================================
torch.save(best_state_iid, "best_fedavg_iid_pretrained.pth")
np.save(
    "metrics_history_fedavg_iid_pretrained.npy",
    metrics_history_fedavg_iid_pretrained,
)

print("\n✅ [IID] Saved:")
print("   • best_fedavg_iid_pretrained.pth")
print("   • metrics_history_fedavg_iid_pretrained.npy")
# Out:
# 🚀 Using Apple Silicon GPU (MPS)
#
# 🔁 [IID] FedAvg Pretrained Round 1/200
#   Client 0 | Train Loss: 0.7555, Train Acc: 0.7063, Local Test Acc: 0.7333
#   Client 1 | Train Loss: 0.6747, Train Acc: 0.7312, Local Test Acc: 0.4491
#   Client 2 | Train Loss: 0.6068, Train Acc: 0.7781, Local Test Acc: 0.8105
#   Client 3 | Train Loss: 0.6949, Train Acc: 0.7344, Local Test Acc: 0.7474
# 🌍 [IID] Global Holdout | Acc: 0.6583, Loss: 0.7902
# 💾 [IID] New BEST Model Saved! Acc = 0.6583
#
# 🔁 [IID] FedAvg Pretrained Round 2/200
#   Client 0 | Train Loss: 0.3785, Train Acc: 0.8719, Local Test Acc: 0.6877
#   Client 1 | Train Loss: 0.3313, Train Acc: 0.8906, Local Test Acc: 0.6316
#   Client 2 | Train Loss: 0.3134, Train Acc: 0.8812, Local Test Acc: 0.7789
#   Client 3 | Train Loss: 0.3136, Train Acc: 0.9094, Local Test Acc: 0.6105
# 🌍 [IID] Global Holdout | Acc: 0.7040, Loss: 0.7925
# 💾 [IID] New BEST Model Saved! Acc = 0.7040
#
# 🔁 [IID] FedAvg Pretrained Round 3/200
#   Client 0 | Train Loss: 0.2122, Train Acc: 0.9187, Local Test Acc: 0.7544
#   Client 1 | Train Loss: 0.3448, Train Acc: 0.8688, Local Test Acc: 0.8175
#   Client 2 | Train Loss: 0.2979, Train Acc: 0.8969, Local Test Acc: 0.8351
#   Client 3 | Train Loss: 0.2572, Train Acc: 0.8938, Local Test Acc: 0.8175
# 🌍 [IID] Global Holdout | Acc: 0.8703, Loss: 0.3382
# 💾 [IID] New BEST Model Saved! Acc = 0.8703
#
# 🔁 [IID] FedAvg Pretrained Round 4/200
#   Client 0 | Train Loss: 0.2764, Train Acc: 0.8906, Local Test Acc: 0.8421
#   Client 1 | Train Loss: 0.2270, Train Acc: 0.9281, Local Test Acc: 0.6632
#   Client 2 | Train Loss: 0.2537, Train Acc: 0.9156, Local Test Acc: 0.8877
#   Client 3 | Train Loss: 0.1950, Train Acc: 0.9156, Local Test Acc: 0.8561
# 🌍 [IID] Global Holdout | Acc: 0.8833, Loss: 0.3388
# 💾 [IID] New BEST Model Saved! Acc = 0.8833
#
# 🔁 [IID] FedAvg Pretrained Round 5/200
#   Client 0 | Train Loss: 0.2539, Train Acc: 0.9031, Local Test Acc: 0.8561
#   Client 1 | Train Loss: 0.1765, Train Acc: 0.9313, Local Test Acc: 0.7579
#   Client 2 | Train Loss: 0.2930, Train Acc: 0.8969, Local Test Acc: 0.8877
#   Client 3 | Train Loss: 0.2312, Train Acc: 0.9156, Local Test Acc: 0.8947
# 🌍 [IID] Global Holdout | Acc: 0.8993, Loss: 0.2859
# 💾 [IID] New BEST Model Saved! Acc = 0.8993
#
# 🔁 [IID] FedAvg Pretrained Round 6/200
#   Client 0 | Train Loss: 0.1944, Train Acc: 0.9313, Local Test Acc: 0.8807
#   Client 1 | Train Loss: 0.2567, Train Acc: 0.9250, Local Test Acc: 0.9053
#   Client 2 | Train Loss: 0.1557, Train Acc: 0.9469, Local Test Acc: 0.8737
#   Client 3 | Train Loss: 0.1815, Train Acc: 0.9437, Local Test Acc: 0.8561
# 🌍 [IID] Global Holdout | Acc: 0.9443, Loss: 0.1657
# 💾 [IID] New BEST Model Saved! Acc = 0.9443
#
# 🔁 [IID] FedAvg Pretrained Round 7/200
#   Client 0 | Train Loss: 0.1733, Train Acc: 0.9344, Local Test Acc: 0.8807
#   Client 1 | Train Loss: 0.1130, Train Acc: 0.9594, Local Test Acc: 0.9193
#   Client 2 | Train Loss: 0.1415, Train Acc: 0.9531, Local Test Acc: 0.8877
#   Client 3 | Train Loss: 0.1389, Train Acc: 0.9500, Local Test Acc: 0.9018
# 🌍 [IID] Global Holdout | Acc: 0.9512, Loss: 0.1560
# 💾 [IID] New BEST Model Saved! Acc = 0.9512
#
# 🔁 [IID] FedAvg Pretrained Round 8/200
#   Client 0 | Train Loss: 0.1132, Train Acc: 0.9594, Local Test Acc: 0.8982
#   Client 1 | Train Loss: 0.1419, Train Acc: 0.9500, Local Test Acc: 0.8772
#   Client 2 | Train Loss: 0.0940, Train Acc: 0.9625, Local Test Acc: 0.9123
#   Client 3 | Train Loss: 0.0984, Train Acc: 0.9750, Local Test Acc: 0.9298
# 🌍 [IID] Global Holdout | Acc: 0.9588, Loss: 0.1248
# 💾 [IID] New BEST Model Saved! Acc = 0.9588
#
# 🔁 [IID] FedAvg Pretrained Round 9/200
#   Client 0 | Train Loss: 0.1569, Train Acc: 0.9313, Local Test Acc: 0.8947
#   Client 1 | Train Loss: 0.1668, Train Acc: 0.9563, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.1373, Train Acc: 0.9688, Local Test Acc: 0.9333
#   Client 3 | Train Loss: 0.1562, Train Acc: 0.9500, Local Test Acc: 0.9439
# 🌍 [IID] Global Holdout | Acc: 0.9573, Loss: 0.1246
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 10/200
#   Client 0 | Train Loss: 0.1136, Train Acc: 0.9531, Local Test Acc: 0.9053
#   Client 1 | Train Loss: 0.1569, Train Acc: 0.9437, Local Test Acc: 0.9193
#   Client 2 | Train Loss: 0.0891, Train Acc: 0.9688, Local Test Acc: 0.9228
#   Client 3 | Train Loss: 0.0710, Train Acc: 0.9719, Local Test Acc: 0.9158
# 🌍 [IID] Global Holdout | Acc: 0.9664, Loss: 0.1055
# 💾 [IID] New BEST Model Saved! Acc = 0.9664
#
# 🔁 [IID] FedAvg Pretrained Round 11/200
#   Client 0 | Train Loss: 0.0406, Train Acc: 0.9812, Local Test Acc: 0.9439
#   Client 1 | Train Loss: 0.0689, Train Acc: 0.9812, Local Test Acc: 0.8596
#   Client 2 | Train Loss: 0.0679, Train Acc: 0.9812, Local Test Acc: 0.9228
#   Client 3 | Train Loss: 0.1058, Train Acc: 0.9625, Local Test Acc: 0.9579
# 🌍 [IID] Global Holdout | Acc: 0.9672, Loss: 0.1181
# 💾 [IID] New BEST Model Saved! Acc = 0.9672
#
# 🔁 [IID] FedAvg Pretrained Round 12/200
#   Client 0 | Train Loss: 0.0417, Train Acc: 0.9844, Local Test Acc: 0.9544
#   Client 1 | Train Loss: 0.0819, Train Acc: 0.9688, Local Test Acc: 0.8596
#   Client 2 | Train Loss: 0.0657, Train Acc: 0.9750, Local Test Acc: 0.9509
#   Client 3 | Train Loss: 0.1377, Train Acc: 0.9563, Local Test Acc: 0.9228
# 🌍 [IID] Global Holdout | Acc: 0.9573, Loss: 0.1320
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 13/200
#   Client 0 | Train Loss: 0.0986, Train Acc: 0.9656, Local Test Acc: 0.7614
#   Client 1 | Train Loss: 0.0739, Train Acc: 0.9656, Local Test Acc: 0.9088
#   Client 2 | Train Loss: 0.0827, Train Acc: 0.9750, Local Test Acc: 0.9544
#   Client 3 | Train Loss: 0.0370, Train Acc: 0.9875, Local Test Acc: 0.9474
# 🌍 [IID] Global Holdout | Acc: 0.9580, Loss: 0.1302
# ⏳ No improvement for 2/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 14/200
#   Client 0 | Train Loss: 0.0666, Train Acc: 0.9812, Local Test Acc: 0.8316
#   Client 1 | Train Loss: 0.0521, Train Acc: 0.9844, Local Test Acc: 0.8246
#   Client 2 | Train Loss: 0.0569, Train Acc: 0.9719, Local Test Acc: 0.9719
#   Client 3 | Train Loss: 0.0567, Train Acc: 0.9750, Local Test Acc: 0.9228
# 🌍 [IID] Global Holdout | Acc: 0.9710, Loss: 0.0733
# 💾 [IID] New BEST Model Saved! Acc = 0.9710
#
# 🔁 [IID] FedAvg Pretrained Round 15/200
#   Client 0 | Train Loss: 0.0214, Train Acc: 0.9906, Local Test Acc: 0.8702
#   Client 1 | Train Loss: 0.0498, Train Acc: 0.9906, Local Test Acc: 0.9404
#   Client 2 | Train Loss: 0.0847, Train Acc: 0.9719, Local Test Acc: 0.9649
#   Client 3 | Train Loss: 0.1024, Train Acc: 0.9625, Local Test Acc: 0.8316
# 🌍 [IID] Global Holdout | Acc: 0.9596, Loss: 0.1167
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 16/200
#   Client 0 | Train Loss: 0.0372, Train Acc: 0.9844, Local Test Acc: 0.8702
#   Client 1 | Train Loss: 0.0476, Train Acc: 0.9906, Local Test Acc: 0.9263
#   Client 2 | Train Loss: 0.0258, Train Acc: 0.9938, Local Test Acc: 0.9263
#   Client 3 | Train Loss: 0.0451, Train Acc: 0.9875, Local Test Acc: 0.9474
# 🌍 [IID] Global Holdout | Acc: 0.9603, Loss: 0.1363
# ⏳ No improvement for 2/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 17/200
#   Client 0 | Train Loss: 0.0494, Train Acc: 0.9906, Local Test Acc: 0.8737
#   Client 1 | Train Loss: 0.0581, Train Acc: 0.9781, Local Test Acc: 0.9298
#   Client 2 | Train Loss: 0.1415, Train Acc: 0.9500, Local Test Acc: 0.9088
#   Client 3 | Train Loss: 0.0476, Train Acc: 0.9844, Local Test Acc: 0.8807
# 🌍 [IID] Global Holdout | Acc: 0.9619, Loss: 0.1435
# ⏳ No improvement for 3/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 18/200
#   Client 0 | Train Loss: 0.0642, Train Acc: 0.9719, Local Test Acc: 0.8947
#   Client 1 | Train Loss: 0.0564, Train Acc: 0.9844, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.0659, Train Acc: 0.9781, Local Test Acc: 0.9123
#   Client 3 | Train Loss: 0.0515, Train Acc: 0.9875, Local Test Acc: 0.9579
# 🌍 [IID] Global Holdout | Acc: 0.9741, Loss: 0.0951
# 💾 [IID] New BEST Model Saved! Acc = 0.9741
#
# 🔁 [IID] FedAvg Pretrained Round 19/200
#   Client 0 | Train Loss: 0.1118, Train Acc: 0.9719, Local Test Acc: 0.8877
#   Client 1 | Train Loss: 0.0141, Train Acc: 0.9969, Local Test Acc: 0.9123
#   Client 2 | Train Loss: 0.0227, Train Acc: 0.9875, Local Test Acc: 0.9579
#   Client 3 | Train Loss: 0.0534, Train Acc: 0.9875, Local Test Acc: 0.9614
# 🌍 [IID] Global Holdout | Acc: 0.9725, Loss: 0.0956
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 20/200
#   Client 0 | Train Loss: 0.0532, Train Acc: 0.9844, Local Test Acc: 0.9228
#   Client 1 | Train Loss: 0.1075, Train Acc: 0.9781, Local Test Acc: 0.9298
#   Client 2 | Train Loss: 0.0446, Train Acc: 0.9781, Local Test Acc: 0.9193
#   Client 3 | Train Loss: 0.0532, Train Acc: 0.9938, Local Test Acc: 0.9298
# 🌍 [IID] Global Holdout | Acc: 0.9710, Loss: 0.1235
# ⏳ No improvement for 2/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 21/200
#   Client 0 | Train Loss: 0.0313, Train Acc: 0.9844, Local Test Acc: 0.7579
#   Client 1 | Train Loss: 0.0326, Train Acc: 0.9906, Local Test Acc: 0.8877
#   Client 2 | Train Loss: 0.0741, Train Acc: 0.9875, Local Test Acc: 0.9754
#   Client 3 | Train Loss: 0.0555, Train Acc: 0.9844, Local Test Acc: 0.7789
# 🌍 [IID] Global Holdout | Acc: 0.9741, Loss: 0.0888
# ⏳ No improvement for 3/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 22/200
#   Client 0 | Train Loss: 0.0090, Train Acc: 1.0000, Local Test Acc: 0.9404
#   Client 1 | Train Loss: 0.0419, Train Acc: 0.9844, Local Test Acc: 0.9333
#   Client 2 | Train Loss: 0.0255, Train Acc: 0.9875, Local Test Acc: 0.9825
#   Client 3 | Train Loss: 0.0445, Train Acc: 0.9906, Local Test Acc: 0.9614
# 🌍 [IID] Global Holdout | Acc: 0.9725, Loss: 0.0822
# ⏳ No improvement for 4/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 23/200
#   Client 0 | Train Loss: 0.0018, Train Acc: 1.0000, Local Test Acc: 0.8456
#   Client 1 | Train Loss: 0.0208, Train Acc: 0.9938, Local Test Acc: 0.8842
#   Client 2 | Train Loss: 0.0121, Train Acc: 0.9969, Local Test Acc: 0.9825
#   Client 3 | Train Loss: 0.0395, Train Acc: 0.9938, Local Test Acc: 0.8702
# 🌍 [IID] Global Holdout | Acc: 0.9771, Loss: 0.1004
# 💾 [IID] New BEST Model Saved! Acc = 0.9771
#
# 🔁 [IID] FedAvg Pretrained Round 24/200
#   Client 0 | Train Loss: 0.0590, Train Acc: 0.9719, Local Test Acc: 0.9614
#   Client 1 | Train Loss: 0.0306, Train Acc: 0.9875, Local Test Acc: 0.9614
#   Client 2 | Train Loss: 0.0508, Train Acc: 0.9812, Local Test Acc: 0.9193
#   Client 3 | Train Loss: 0.0093, Train Acc: 0.9969, Local Test Acc: 0.9649
# 🌍 [IID] Global Holdout | Acc: 0.9741, Loss: 0.0866
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 25/200
#   Client 0 | Train Loss: 0.0159, Train Acc: 0.9938, Local Test Acc: 0.8632
#   Client 1 | Train Loss: 0.0301, Train Acc: 0.9938, Local Test Acc: 0.9439
#   Client 2 | Train Loss: 0.1087, Train Acc: 0.9688, Local Test Acc: 0.8281
#   Client 3 | Train Loss: 0.0097, Train Acc: 0.9969, Local Test Acc: 0.9474
# 🌍 [IID] Global Holdout | Acc: 0.9733, Loss: 0.0927
# ⏳ No improvement for 2/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 26/200
#   Client 0 | Train Loss: 0.0256, Train Acc: 0.9906, Local Test Acc: 0.9298
#   Client 1 | Train Loss: 0.0296, Train Acc: 0.9938, Local Test Acc: 0.9544
#   Client 2 | Train Loss: 0.0270, Train Acc: 0.9906, Local Test Acc: 0.9263
#   Client 3 | Train Loss: 0.0048, Train Acc: 0.9969, Local Test Acc: 0.8702
# 🌍 [IID] Global Holdout | Acc: 0.9695, Loss: 0.1303
# ⏳ No improvement for 3/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 27/200
#   Client 0 | Train Loss: 0.0155, Train Acc: 0.9906, Local Test Acc: 0.9579
#   Client 1 | Train Loss: 0.1078, Train Acc: 0.9812, Local Test Acc: 0.7860
#   Client 2 | Train Loss: 0.0266, Train Acc: 0.9938, Local Test Acc: 0.9789
#   Client 3 | Train Loss: 0.0006, Train Acc: 1.0000, Local Test Acc: 0.8982
# 🌍 [IID] Global Holdout | Acc: 0.9771, Loss: 0.0873
# ⏳ No improvement for 4/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 28/200
#   Client 0 | Train Loss: 0.0152, Train Acc: 0.9906, Local Test Acc: 0.7439
#   Client 1 | Train Loss: 0.0521, Train Acc: 0.9906, Local Test Acc: 0.8667
#   Client 2 | Train Loss: 0.0103, Train Acc: 0.9969, Local Test Acc: 0.8947
#   Client 3 | Train Loss: 0.0455, Train Acc: 0.9906, Local Test Acc: 0.9018
# 🌍 [IID] Global Holdout | Acc: 0.9786, Loss: 0.0873
# 💾 [IID] New BEST Model Saved! Acc = 0.9786
#
# 🔁 [IID] FedAvg Pretrained Round 29/200
#   Client 0 | Train Loss: 0.0163, Train Acc: 0.9938, Local Test Acc: 0.9544
#   Client 1 | Train Loss: 0.0177, Train Acc: 0.9969, Local Test Acc: 0.9544
#   Client 2 | Train Loss: 0.0060, Train Acc: 0.9969, Local Test Acc: 0.7158
#   Client 3 | Train Loss: 0.0111, Train Acc: 0.9906, Local Test Acc: 0.9228
# 🌍 [IID] Global Holdout | Acc: 0.9809, Loss: 0.0742
# 💾 [IID] New BEST Model Saved! Acc = 0.9809
#
# 🔁 [IID] FedAvg Pretrained Round 30/200
#   Client 0 | Train Loss: 0.0060, Train Acc: 0.9938, Local Test Acc: 0.8526
#   Client 1 | Train Loss: 0.0251, Train Acc: 0.9906, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.0076, Train Acc: 0.9969, Local Test Acc: 0.9333
#   Client 3 | Train Loss: 0.0174, Train Acc: 0.9938, Local Test Acc: 0.8947
# 🌍 [IID] Global Holdout | Acc: 0.9832, Loss: 0.0754
# 💾 [IID] New BEST Model Saved! Acc = 0.9832
#
# 🔁 [IID] FedAvg Pretrained Round 31/200
#   Client 0 | Train Loss: 0.0062, Train Acc: 0.9969, Local Test Acc: 0.7754
#   Client 1 | Train Loss: 0.0696, Train Acc: 0.9938, Local Test Acc: 0.9053
#   Client 2 | Train Loss: 0.0042, Train Acc: 0.9969, Local Test Acc: 0.9333
#   Client 3 | Train Loss: 0.0540, Train Acc: 0.9875, Local Test Acc: 0.9649
# 🌍 [IID] Global Holdout | Acc: 0.9794, Loss: 0.0776
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 32/200
#   Client 0 | Train Loss: 0.0033, Train Acc: 1.0000, Local Test Acc: 0.8351
#   Client 1 | Train Loss: 0.0222, Train Acc: 0.9906, Local Test Acc: 0.9263
#   Client 2 | Train Loss: 0.1112, Train Acc: 0.9781, Local Test Acc: 0.9825
#   Client 3 | Train Loss: 0.0157, Train Acc: 0.9938, Local Test Acc: 0.9298
# 🌍 [IID] Global Holdout | Acc: 0.9855, Loss: 0.0582
# 💾 [IID] New BEST Model Saved! Acc = 0.9855
#
# 🔁 [IID] FedAvg Pretrained Round 33/200
#   Client 0 | Train Loss: 0.0575, Train Acc: 0.9875, Local Test Acc: 0.9404
#   Client 1 | Train Loss: 0.0274, Train Acc: 0.9875, Local Test Acc: 0.9333
#   Client 2 | Train Loss: 0.0550, Train Acc: 0.9938, Local Test Acc: 0.6807
#   Client 3 | Train Loss: 0.0037, Train Acc: 0.9969, Local Test Acc: 0.8316
# 🌍 [IID] Global Holdout | Acc: 0.9664, Loss: 0.1556
# ⏳ No improvement for 1/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 34/200
#   Client 0 | Train Loss: 0.0693, Train Acc: 0.9906, Local Test Acc: 0.9474
#   Client 1 | Train Loss: 0.0293, Train Acc: 0.9938, Local Test Acc: 0.7649
#   Client 2 | Train Loss: 0.0307, Train Acc: 0.9969, Local Test Acc: 0.9333
#   Client 3 | Train Loss: 0.0243, Train Acc: 0.9938, Local Test Acc: 0.9053
# 🌍 [IID] Global Holdout | Acc: 0.9809, Loss: 0.0790
# ⏳ No improvement for 2/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 35/200
#   Client 0 | Train Loss: 0.0036, Train Acc: 1.0000, Local Test Acc: 0.8807
#   Client 1 | Train Loss: 0.0094, Train Acc: 0.9938, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.0484, Train Acc: 0.9812, Local Test Acc: 0.9614
#   Client 3 | Train Loss: 0.0567, Train Acc: 0.9938, Local Test Acc: 0.9684
# 🌍 [IID] Global Holdout | Acc: 0.9725, Loss: 0.1180
# ⏳ No improvement for 3/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 36/200
#   Client 0 | Train Loss: 0.0044, Train Acc: 0.9969, Local Test Acc: 0.8561
#   Client 1 | Train Loss: 0.0317, Train Acc: 0.9906, Local Test Acc: 0.9123
#   Client 2 | Train Loss: 0.0016, Train Acc: 1.0000, Local Test Acc: 0.8000
#   Client 3 | Train Loss: 0.0042, Train Acc: 1.0000, Local Test Acc: 0.9509
# 🌍 [IID] Global Holdout | Acc: 0.9611, Loss: 0.2167
# ⏳ No improvement for 4/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 37/200
#   Client 0 | Train Loss: 0.0031, Train Acc: 1.0000, Local Test Acc: 0.8070
#   Client 1 | Train Loss: 0.0034, Train Acc: 0.9969, Local Test Acc: 0.8386
#   Client 2 | Train Loss: 0.0011, Train Acc: 1.0000, Local Test Acc: 0.9368
#   Client 3 | Train Loss: 0.0011, Train Acc: 1.0000, Local Test Acc: 0.9474
# 🌍 [IID] Global Holdout | Acc: 0.9764, Loss: 0.1197
# ⏳ No improvement for 5/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 38/200
#   Client 0 | Train Loss: 0.0229, Train Acc: 0.9938, Local Test Acc: 0.9474
#   Client 1 | Train Loss: 0.0005, Train Acc: 1.0000, Local Test Acc: 0.6596
#   Client 2 | Train Loss: 0.0859, Train Acc: 0.9875, Local Test Acc: 0.9930
#   Client 3 | Train Loss: 0.0270, Train Acc: 0.9906, Local Test Acc: 0.9088
# 🌍 [IID] Global Holdout | Acc: 0.9825, Loss: 0.0872
# ⏳ No improvement for 6/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 39/200
#   Client 0 | Train Loss: 0.0660, Train Acc: 0.9906, Local Test Acc: 0.9439
#   Client 1 | Train Loss: 0.0340, Train Acc: 0.9938, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.0153, Train Acc: 0.9969, Local Test Acc: 0.9193
#   Client 3 | Train Loss: 0.0158, Train Acc: 0.9938, Local Test Acc: 0.9719
# 🌍 [IID] Global Holdout | Acc: 0.9840, Loss: 0.0883
# ⏳ No improvement for 7/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 40/200
#   Client 0 | Train Loss: 0.0016, Train Acc: 1.0000, Local Test Acc: 0.7544
#   Client 1 | Train Loss: 0.0180, Train Acc: 0.9969, Local Test Acc: 0.9649
#   Client 2 | Train Loss: 0.0115, Train Acc: 0.9969, Local Test Acc: 0.8877
#   Client 3 | Train Loss: 0.0098, Train Acc: 0.9938, Local Test Acc: 0.9158
# 🌍 [IID] Global Holdout | Acc: 0.9497, Loss: 0.2496
# ⏳ No improvement for 8/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 41/200
#   Client 0 | Train Loss: 0.0023, Train Acc: 1.0000, Local Test Acc: 0.6351
#   Client 1 | Train Loss: 0.0270, Train Acc: 0.9938, Local Test Acc: 0.9228
#   Client 2 | Train Loss: 0.0182, Train Acc: 0.9969, Local Test Acc: 0.9684
#   Client 3 | Train Loss: 0.0310, Train Acc: 0.9938, Local Test Acc: 0.7404
# 🌍 [IID] Global Holdout | Acc: 0.9825, Loss: 0.0938
# ⏳ No improvement for 9/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 42/200
#   Client 0 | Train Loss: 0.0003, Train Acc: 1.0000, Local Test Acc: 0.8526
#   Client 1 | Train Loss: 0.0021, Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 2 | Train Loss: 0.0684, Train Acc: 0.9844, Local Test Acc: 0.9544
#   Client 3 | Train Loss: 0.0228, Train Acc: 0.9906, Local Test Acc: 0.9544
# 🌍 [IID] Global Holdout | Acc: 0.9825, Loss: 0.0862
# ⏳ No improvement for 10/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 43/200
#   Client 0 | Train Loss: 0.0129, Train Acc: 0.9938, Local Test Acc: 0.9614
#   Client 1 | Train Loss: 0.0548, Train Acc: 0.9781, Local Test Acc: 0.8877
#   Client 2 | Train Loss: 0.0213, Train Acc: 0.9969, Local Test Acc: 0.9789
#   Client 3 | Train Loss: 0.0376, Train Acc: 0.9906, Local Test Acc: 0.9193
# 🌍 [IID] Global Holdout | Acc: 0.9580, Loss: 0.2336
# ⏳ No improvement for 11/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 44/200
#   Client 0 | Train Loss: 0.0312, Train Acc: 0.9969, Local Test Acc: 0.9368
#   Client 1 | Train Loss: 0.0291, Train Acc: 0.9906, Local Test Acc: 0.9333
#   Client 2 | Train Loss: 0.0613, Train Acc: 0.9906, Local Test Acc: 0.8982
#   Client 3 | Train Loss: 0.0445, Train Acc: 0.9875, Local Test Acc: 0.9544
# 🌍 [IID] Global Holdout | Acc: 0.9825, Loss: 0.1031
# ⏳ No improvement for 12/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 45/200
#   Client 0 | Train Loss: 0.0156, Train Acc: 0.9969, Local Test Acc: 0.9158
#   Client 1 | Train Loss: 0.0084, Train Acc: 0.9969, Local Test Acc: 0.9474
#   Client 2 | Train Loss: 0.0065, Train Acc: 0.9969, Local Test Acc: 0.7053
#   Client 3 | Train Loss: 0.0947, Train Acc: 0.9906, Local Test Acc: 0.8526
# 🌍 [IID] Global Holdout | Acc: 0.9703, Loss: 0.1745
# ⏳ No improvement for 13/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 46/200
#   Client 0 | Train Loss: 0.0146, Train Acc: 0.9969, Local Test Acc: 0.8596
#   Client 1 | Train Loss: 0.0215, Train Acc: 0.9938, Local Test Acc: 0.9298
#   Client 2 | Train Loss: 0.0168, Train Acc: 0.9969, Local Test Acc: 0.9404
#   Client 3 | Train Loss: 0.0020, Train Acc: 1.0000, Local Test Acc: 0.5860
# 🌍 [IID] Global Holdout | Acc: 0.9649, Loss: 0.1570
# ⏳ No improvement for 14/15 rounds.
#
# 🔁 [IID] FedAvg Pretrained Round 47/200
#   Client 0 | Train Loss: 0.0012, Train Acc: 1.0000, Local Test Acc: 0.9544
#   Client 1 | Train Loss: 0.0391, Train Acc: 0.9875, Local Test Acc: 0.9614
#   Client 2 | Train Loss: 0.0233, Train Acc: 0.9938, Local Test Acc: 0.7965
#   Client 3 | Train Loss: 0.0000, Train Acc: 1.0000, Local Test Acc: 0.9579
# 🌍 [IID] Global Holdout | Acc: 0.9764, Loss: 0.1258
# ⏳ No improvement for 15/15 rounds.
#
# 🛑 Early stopping triggered! Training converged.
#
# ✅ [IID] Saved:
#    • best_fedavg_iid_pretrained.pth
#    • metrics_history_fedavg_iid_pretrained.npy

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# ============================================================
#      LOAD METRICS FROM FEDAVG PRETRAINED (IID RUN)
# ============================================================

rounds = metrics_history_fedavg_iid_pretrained["round"]
holdout_metrics = metrics_history_fedavg_iid_pretrained["holdout"]

accs = [m["acc"] for m in holdout_metrics]
losses = [m["loss"] for m in holdout_metrics]

# ============================================================
#                PLOT GLOBAL ACCURACY PER ROUND
# ============================================================

plt.figure(figsize=(7, 5))
plt.plot(rounds, accs, marker='o', linewidth=2)
plt.title("FedAvg (IID Pretrained ResNet18) — Global Accuracy per Round")
plt.xlabel("Round")
plt.ylabel("Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()

# ============================================================
#                PLOT GLOBAL LOSS PER ROUND
# ============================================================

plt.figure(figsize=(7, 5))
plt.plot(rounds, losses, marker='o', color="red", linewidth=2)
plt.title("FedAvg (IID Pretrained ResNet18) — Global Loss per Round")
plt.xlabel("Round")
plt.ylabel("Loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# ============================================================
#         SAVE ROUND/ACC/LOSS ARRAYS FOR COMPARISON
# ============================================================

np.save("fedavg_iid_pretrained_rounds.npy", np.array(rounds))
np.save("fedavg_iid_pretrained_acc.npy", np.array(accs))
np.save("fedavg_iid_pretrained_loss.npy", np.array(losses))

print("Saved: fedavg_iid_pretrained_rounds.npy, fedavg_iid_pretrained_acc.npy, fedavg_iid_pretrained_loss.npy")

# ============================================================
#         LOAD BEST FEDAVG PRETRAINED IID MODEL
# ============================================================

best_model_fedavg = create_pretrained_resnet18_iid(NUM_CLASSES_IID)
best_model_fedavg.load_state_dict(torch.load("best_fedavg_iid_pretrained.pth"))
best_model_fedavg.to(DEVICE)
best_model_fedavg.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in holdout_loader_iid:   # correct name from your training script
        x = x.to(DEVICE)
        y = y.to(DEVICE)

        logits = best_model_fedavg(x)
        preds = logits.argmax(dim=1)

        all_preds.append(preds.cpu())
        all_labels.append(y.cpu())

all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

# ============================================================
#                  HOLDOUT METRIC COMPUTATION
# ============================================================

acc  = (all_preds == all_labels).mean()
prec = precision_score(all_labels, all_preds, average="macro")
rec  = recall_score(all_labels, all_preds, average="macro")
f1   = f1_score(all_labels, all_preds, average="macro")

print("\n📊 FEDAVG IID PRETRAINED — GLOBAL HOLDOUT METRICS")
print(f"Accuracy :  {acc:.4f}")
print(f"Precision:  {prec:.4f}")
print(f"Recall   :  {rec:.4f}")
print(f"F1-Score :  {f1:.4f}")

# ============================================================
#                  CONFUSION MATRIX
# ============================================================

cm = confusion_matrix(all_labels, all_preds)
class_names = train_dataset.classes  # correct class names

plt.figure(figsize=(8, 6))
sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Blues",
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix — FedAvg (IID Pretrained)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# ============================================================
#            SAVE CONFUSION MATRIX
# ============================================================

np.save("fedavg_iid_pretrained_confusion_matrix.npy", cm)
print("\nSaved confusion matrix → fedavg_iid_pretrained_confusion_matrix.npy")
# Out:
# Saved: fedavg_iid_pretrained_rounds.npy, fedavg_iid_pretrained_acc.npy, fedavg_iid_pretrained_loss.npy
#
# 📊 FEDAVG IID PRETRAINED — GLOBAL HOLDOUT METRICS
# Accuracy :  0.9855
# Precision:  0.9845
# Recall   :  0.9843
# F1-Score :  0.9844
# Saved confusion matrix → fedavg_iid_pretrained_confusion_matrix.npy

# %%
# ============================================================
#        FEDPROX (IID) — PRETRAINED RESNET18 + ITERATIONS
# ============================================================

import random
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from torch.utils.data import DataLoader


# ============================================================
#                    DEVICE SETUP
# ============================================================
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
    print("🚀 Using Apple Silicon GPU (MPS)")
elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print("🚀 Using NVIDIA GPU (CUDA)")
else:
    DEVICE = torch.device("cpu")
    print("🖥 Using CPU")


# ============================================================
#                       CONFIG
# ============================================================
SEED = 77
NUM_ROUNDS = 200                 # max FL rounds
LOCAL_ITERATIONS = 10            # 🔥 iteration-based (like FedAvg version)
LR = 3e-4
FEDPROX_MU = 0.1                 # 🔥 HIGH MU as requested
BATCH_SIZE = 32

NUM_CLIENTS = len(client_data)
NUM_CLASSES = len(train_dataset.classes)

PATIENCE = 15                    # Early stopping patience


# ============================================================
#                    REPRODUCIBILITY
# ============================================================
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

crit_ce = nn.CrossEntropyLoss()


# ============================================================
#     PRETRAINED RESNET18 WITH FREEZING STRATEGY (IID)
# ============================================================
def create_pretrained_resnet18_fedprox(num_classes: int) -> nn.Module:
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

    # freeze early layers
    for p in model.conv1.parameters():  p.requires_grad = False
    for p in model.bn1.parameters():    p.requires_grad = False
    for p in model.layer1.parameters(): p.requires_grad = False
    for p in model.layer2.parameters(): p.requires_grad = False

    # train deeper layers
    for p in model.layer3.parameters(): p.requires_grad = True
    for p in model.layer4.parameters(): p.requires_grad = True

    # replace classifier
    in_f = model.fc.in_features
    model.fc = nn.Linear(in_f, num_classes)

    return model


# ============================================================
#               FEDPROX LOCAL TRAINING (ITERATIONS)
# ============================================================
def train_fedprox_iterations(
    model, loader, device, optimizer, global_params, mu, num_steps
):
    """
    FedProx local update using iterations instead of epochs.
    Implements: loss = CE + (mu/2) * ||w - w_global||^2
    """

    model.train()
    iterator = iter(loader)

    tot_loss, tot_corr, tot = 0.0, 0, 0

    for step in range(num_steps):

        try:
            x, y = next(iterator)
        except StopIteration:
            iterator = iter(loader)
            x, y = next(iterator)

        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        ce_loss = crit_ce(logits, y)

        # Proximal term
        prox_term = 0.0
        for name, param in model.named_parameters():
            if param.requires_grad:
                prox_term += ((param - global_params[name]) ** 2).sum()

        loss = ce_loss + (mu / 2.0) * prox_term
        loss.backward()
        optimizer.step()

        bs = x.size(0)
        tot_loss += loss.item() * bs
        tot_corr += (logits.argmax(1) == y).sum().item()
        tot += bs

    return {"loss": tot_loss / tot, "acc": tot_corr / tot}


# ============================================================
#                   EVALUATION
# ============================================================
@torch.no_grad()
def evaluate_fedprox(model, loader, device):
    model.eval()
    tot_loss, tot_corr, tot = 0.0, 0, 0

    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = crit_ce(logits, y)

        bs = x.size(0)
        tot_loss += loss.item() * bs
        tot_corr += (logits.argmax(1) == y).sum().item()
        tot += bs

    return {"loss": tot_loss / tot, "acc": tot_corr / tot}


# ============================================================
#            CLIENT DATALOADERS (IID)
# ============================================================
client_train_loaders = []
client_test_loaders = []

for train_subset, test_subset in client_data:
    client_train_loaders.append(
        DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    )
    client_test_loaders.append(
        DataLoader(test_subset, batch_size=BATCH_SIZE, shuffle=False)
    )

holdout_loader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False
)


# ============================================================
#            GLOBAL MODEL + METRICS + EARLY STOPPING
# ============================================================
global_model = create_pretrained_resnet18_fedprox(NUM_CLASSES).to(DEVICE)

best_acc = -1.0
best_state = None
no_improve_count = 0

metrics_history_fedprox_iid_pretrained = {
    "round": [],
    "holdout": [],
    "clients": {k: [] for k in range(NUM_CLIENTS)},
}


# ============================================================
#                     FEDPROX LOOP (IID)
# ============================================================
for rnd in range(NUM_ROUNDS):

    print(f"\n🔁 [IID] FedProx Round {rnd + 1}/{NUM_ROUNDS}")

    local_states = []

    # copy global parameters once per round
    global_params = {
        name: p.detach().clone().to(DEVICE)
        for name, p in global_model.named_parameters()
    }

    # ----- CLIENT TRAINING -----
    for k in range(NUM_CLIENTS):

        local_model = copy.deepcopy(global_model).to(DEVICE)

        optimizer = optim.Adam(
            (p for p in local_model.parameters() if p.requires_grad),
            lr=LR,
        )

        # 🔥 iteration-based FedProx update
        train_metrics = train_fedprox_iterations(
            local_model,
            client_train_loaders[k],
            DEVICE,
            optimizer,
            global_params,
            FEDPROX_MU,
            LOCAL_ITERATIONS,
        )

        # collect local models
        local_states.append({
            name: param.cpu() for name, param in local_model.state_dict().items()
        })

        # local eval
        client_metric = evaluate_fedprox(local_model, client_test_loaders[k], DEVICE)
        metrics_history_fedprox_iid_pretrained["clients"][k].append(client_metric)

        print(f"  Client {k} | "
              f"Train Acc: {train_metrics['acc']:.4f}, "
              f"Local Test Acc: {client_metric['acc']:.4f}")

    # ----- FEDERATED AVERAGING -----
    new_state = {}
    for key in global_model.state_dict().keys():
        stacked = torch.stack([state[key] for state in local_states], dim=0)

        if stacked.dtype.is_floating_point:
            new_state[key] = stacked.mean(dim=0)
        else:
            new_state[key] = stacked[0]

    global_model.load_state_dict(new_state)

    # ----- GLOBAL HOLDOUT -----
    holdout_metric = evaluate_fedprox(global_model, holdout_loader, DEVICE)

    metrics_history_fedprox_iid_pretrained["round"].append(rnd + 1)
    metrics_history_fedprox_iid_pretrained["holdout"].append(holdout_metric)

    print(f"🌍 Global Holdout | Acc: {holdout_metric['acc']:.4f}, "
          f"Loss: {holdout_metric['loss']:.4f}")

    # ----- EARLY STOPPING -----
    if holdout_metric["acc"] > best_acc:
        best_acc = holdout_metric["acc"]
        best_state = copy.deepcopy(global_model.state_dict())
        no_improve_count = 0
        print(f"💾 New BEST Model! Acc = {best_acc:.4f}")
    else:
        no_improve_count += 1
        print(f"⏳ No improvement for {no_improve_count}/{PATIENCE} rounds")

    if no_improve_count >= PATIENCE:
        print("\n🛑 Early stopping triggered!")
        break


# ============================================================
#                      SAVE RESULTS
# ============================================================
torch.save(best_state, "best_fedprox_iid_pretrained.pth")
np.save("metrics_history_fedprox_iid_pretrained.npy",
        metrics_history_fedprox_iid_pretrained)

print("\n✅ Saved:")
print("   • best_fedprox_iid_pretrained.pth")
print("   • metrics_history_fedprox_iid_pretrained.npy")
# Out:
# 🚀 Using Apple Silicon GPU (MPS)
#
# 🔁 [IID] FedProx Round 1/200
#   Client 0 | Train Acc: 0.7031, Local Test Acc: 0.7333
#   Client 1 | Train Acc: 0.7344, Local Test Acc: 0.4316
#   Client 2 | Train Acc: 0.7812, Local Test Acc: 0.7895
#   Client 3 | Train Acc: 0.7375, Local Test Acc: 0.7404
# 🌍 Global Holdout | Acc: 0.6476, Loss: 0.8110
# 💾 New BEST Model! Acc = 0.6476
#
# 🔁 [IID] FedProx Round 2/200
#   Client 0 | Train Acc: 0.8656, Local Test Acc: 0.7193
#   Client 1 | Train Acc: 0.8969, Local Test Acc: 0.6351
#   Client 2 | Train Acc: 0.8812, Local Test Acc: 0.7789
#   Client 3 | Train Acc: 0.9094, Local Test Acc: 0.6947
# 🌍 Global Holdout | Acc: 0.7216, Loss: 0.7089
# 💾 New BEST Model! Acc = 0.7216
#
# 🔁 [IID] FedProx Round 3/200
#   Client 0 | Train Acc: 0.9250, Local Test Acc: 0.7298
#   Client 1 | Train Acc: 0.8625, Local Test Acc: 0.8421
#   Client 2 | Train Acc: 0.9031, Local Test Acc: 0.8316
#   Client 3 | Train Acc: 0.9000, Local Test Acc: 0.8246
# 🌍 Global Holdout | Acc: 0.8642, Loss: 0.3478
# 💾 New BEST Model! Acc = 0.8642
#
# 🔁 [IID] FedProx Round 4/200
#   Client 0 | Train Acc: 0.8969, Local Test Acc: 0.8386
#   Client 1 | Train Acc: 0.9250, Local Test Acc: 0.6386
#   Client 2 | Train Acc: 0.9125, Local Test Acc: 0.8807
#   Client 3 | Train Acc: 0.9281, Local Test Acc: 0.8561
# 🌍 Global Holdout | Acc: 0.8780, Loss: 0.3461
# 💾 New BEST Model! Acc = 0.8780
#
# 🔁 [IID] FedProx Round 5/200
#   Client 0 | Train Acc: 0.9062, Local Test Acc: 0.8737
#   Client 1 | Train Acc: 0.9344, Local Test Acc: 0.7439
#   Client 2 | Train Acc: 0.8969, Local Test Acc: 0.9018
#   Client 3 | Train Acc: 0.9250, Local Test Acc: 0.8947
# 🌍 Global Holdout | Acc: 0.8833, Loss: 0.3078
# 💾 New BEST Model! Acc = 0.8833
#
# 🔁 [IID] FedProx Round 6/200
#   Client 0 | Train Acc: 0.9250, Local Test Acc: 0.9158
#   Client 1 | Train Acc: 0.9219, Local Test Acc: 0.8947
#   Client 2 | Train Acc: 0.9531, Local Test Acc: 0.8877
#   Client 3 | Train Acc: 0.9500, Local Test Acc: 0.8386
# 🌍 Global Holdout | Acc: 0.9352, Loss: 0.1864
# 💾 New BEST Model! Acc = 0.9352
#
# 🔁 [IID] FedProx Round 7/200
#   Client 0 | Train Acc: 0.9469, Local Test Acc: 0.9404
#   Client 1 | Train Acc: 0.9594, Local Test Acc: 0.9333
#   Client 2 | Train Acc: 0.9531, Local Test Acc: 0.9123
#   Client 3 | Train Acc: 0.9531, Local Test Acc: 0.9333
# 🌍 Global Holdout | Acc: 0.9481, Loss: 0.1513
# 💾 New BEST Model! Acc = 0.9481
#
# 🔁 [IID] FedProx Round 8/200
#   Client 0 | Train Acc: 0.9625, Local Test Acc: 0.9053
#   Client 1 | Train Acc: 0.9531, Local Test Acc: 0.9404
#   Client 2 | Train Acc: 0.9781, Local Test Acc: 0.9439
#   Client 3 | Train Acc: 0.9750, Local Test Acc: 0.9333
# 🌍 Global Holdout | Acc: 0.9596, Loss: 0.1115
# 💾 New BEST Model! Acc = 0.9596
#
# 🔁 [IID] FedProx Round 9/200
#   Client 0 | Train Acc: 0.9437, Local Test Acc: 0.9053
#   Client 1 | Train Acc: 0.9656, Local Test Acc: 0.9333
#   Client 2 | Train Acc: 0.9719, Local Test Acc: 0.9649
#   Client 3 | Train Acc: 0.9594, Local Test Acc: 0.9509
# 🌍 Global Holdout | Acc: 0.9588, Loss: 0.1085
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 10/200
#   Client 0 | Train Acc: 0.9625, Local Test Acc: 0.9228
#   Client 1 | Train Acc: 0.9469, Local Test Acc: 0.9263
#   Client 2 | Train Acc: 0.9750, Local Test Acc: 0.9474
#   Client 3 | Train Acc: 0.9906, Local Test Acc: 0.9474
# 🌍 Global Holdout | Acc: 0.9710, Loss: 0.0845
# 💾 New BEST Model! Acc = 0.9710
#
# 🔁 [IID] FedProx Round 11/200
#   Client 0 | Train Acc: 0.9812, Local Test Acc: 0.9439
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.8842
#   Client 2 | Train Acc: 0.9812, Local Test Acc: 0.9368
#   Client 3 | Train Acc: 0.9594, Local Test Acc: 0.9544
# 🌍 Global Holdout | Acc: 0.9619, Loss: 0.1073
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 12/200
#   Client 0 | Train Acc: 0.9875, Local Test Acc: 0.9404
#   Client 1 | Train Acc: 0.9781, Local Test Acc: 0.9263
#   Client 2 | Train Acc: 0.9781, Local Test Acc: 0.9649
#   Client 3 | Train Acc: 0.9656, Local Test Acc: 0.9649
# 🌍 Global Holdout | Acc: 0.9687, Loss: 0.0831
# ⏳ No improvement for 2/15 rounds
#
# 🔁 [IID] FedProx Round 13/200
#   Client 0 | Train Acc: 0.9719, Local Test Acc: 0.7719
#   Client 1 | Train Acc: 0.9750, Local Test Acc: 0.7404
#   Client 2 | Train Acc: 0.9844, Local Test Acc: 0.9754
#   Client 3 | Train Acc: 0.9938, Local Test Acc: 0.9439
# 🌍 Global Holdout | Acc: 0.9451, Loss: 0.1458
# ⏳ No improvement for 3/15 rounds
#
# 🔁 [IID] FedProx Round 14/200
#   Client 0 | Train Acc: 0.9781, Local Test Acc: 0.9509
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.9088
#   Client 2 | Train Acc: 0.9875, Local Test Acc: 0.9684
#   Client 3 | Train Acc: 0.9875, Local Test Acc: 0.9579
# 🌍 Global Holdout | Acc: 0.9680, Loss: 0.0911
# ⏳ No improvement for 4/15 rounds
#
# 🔁 [IID] FedProx Round 15/200
#   Client 0 | Train Acc: 0.9938, Local Test Acc: 0.8877
#   Client 1 | Train Acc: 0.9938, Local Test Acc: 0.9158
#   Client 2 | Train Acc: 0.9875, Local Test Acc: 0.9754
#   Client 3 | Train Acc: 0.9656, Local Test Acc: 0.9263
# 🌍 Global Holdout | Acc: 0.9710, Loss: 0.0748
# ⏳ No improvement for 5/15 rounds
#
# 🔁 [IID] FedProx Round 16/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9614
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.9474
#   Client 2 | Train Acc: 0.9969, Local Test Acc: 0.9404
#   Client 3 | Train Acc: 0.9875, Local Test Acc: 0.9474
# 🌍 Global Holdout | Acc: 0.9641, Loss: 0.1076
# ⏳ No improvement for 6/15 rounds
#
# 🔁 [IID] FedProx Round 17/200
#   Client 0 | Train Acc: 0.9969, Local Test Acc: 0.8702
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.9439
#   Client 2 | Train Acc: 0.9594, Local Test Acc: 0.9158
#   Client 3 | Train Acc: 0.9812, Local Test Acc: 0.9088
# 🌍 Global Holdout | Acc: 0.9733, Loss: 0.0741
# 💾 New BEST Model! Acc = 0.9733
#
# 🔁 [IID] FedProx Round 18/200
#   Client 0 | Train Acc: 0.9656, Local Test Acc: 0.8947
#   Client 1 | Train Acc: 0.9938, Local Test Acc: 0.9333
#   Client 2 | Train Acc: 0.9938, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 0.9938, Local Test Acc: 0.9649
# 🌍 Global Holdout | Acc: 0.9725, Loss: 0.0836
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 19/200
#   Client 0 | Train Acc: 0.9781, Local Test Acc: 0.9368
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9509
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9298
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9439
# 🌍 Global Holdout | Acc: 0.9748, Loss: 0.0742
# 💾 New BEST Model! Acc = 0.9748
#
# 🔁 [IID] FedProx Round 20/200
#   Client 0 | Train Acc: 0.9906, Local Test Acc: 0.9614
#   Client 1 | Train Acc: 0.9875, Local Test Acc: 0.9368
#   Client 2 | Train Acc: 0.9875, Local Test Acc: 0.9684
#   Client 3 | Train Acc: 0.9906, Local Test Acc: 0.9544
# 🌍 Global Holdout | Acc: 0.9756, Loss: 0.0754
# 💾 New BEST Model! Acc = 0.9756
#
# 🔁 [IID] FedProx Round 21/200
#   Client 0 | Train Acc: 0.9938, Local Test Acc: 0.9404
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.9614
#   Client 2 | Train Acc: 0.9844, Local Test Acc: 0.9614
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9018
# 🌍 Global Holdout | Acc: 0.9794, Loss: 0.0626
# 💾 New BEST Model! Acc = 0.9794
#
# 🔁 [IID] FedProx Round 22/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9684
#   Client 2 | Train Acc: 0.9906, Local Test Acc: 0.9719
#   Client 3 | Train Acc: 0.9781, Local Test Acc: 0.9825
# 🌍 Global Holdout | Acc: 0.9771, Loss: 0.0599
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 23/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9404
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9509
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9895
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.8526
# 🌍 Global Holdout | Acc: 0.9687, Loss: 0.0951
# ⏳ No improvement for 2/15 rounds
#
# 🔁 [IID] FedProx Round 24/200
#   Client 0 | Train Acc: 0.9844, Local Test Acc: 0.9544
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9368
#   Client 2 | Train Acc: 0.9938, Local Test Acc: 0.9754
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9684
# 🌍 Global Holdout | Acc: 0.9779, Loss: 0.0751
# ⏳ No improvement for 3/15 rounds
#
# 🔁 [IID] FedProx Round 25/200
#   Client 0 | Train Acc: 0.9938, Local Test Acc: 0.9474
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 0.9750, Local Test Acc: 0.9544
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9018
# 🌍 Global Holdout | Acc: 0.9786, Loss: 0.0639
# ⏳ No improvement for 4/15 rounds
#
# 🔁 [IID] FedProx Round 26/200
#   Client 0 | Train Acc: 0.9906, Local Test Acc: 0.9404
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9474
#   Client 2 | Train Acc: 0.9938, Local Test Acc: 0.9719
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9684
# 🌍 Global Holdout | Acc: 0.9733, Loss: 0.0831
# ⏳ No improvement for 5/15 rounds
#
# 🔁 [IID] FedProx Round 27/200
#   Client 0 | Train Acc: 0.9844, Local Test Acc: 0.9439
#   Client 1 | Train Acc: 0.9875, Local Test Acc: 0.9579
#   Client 2 | Train Acc: 0.9906, Local Test Acc: 0.9614
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9794, Loss: 0.0866
# ⏳ No improvement for 6/15 rounds
#
# 🔁 [IID] FedProx Round 28/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 1 | Train Acc: 0.9938, Local Test Acc: 0.9614
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9860
# 🌍 Global Holdout | Acc: 0.9802, Loss: 0.0712
# 💾 New BEST Model! Acc = 0.9802
#
# 🔁 [IID] FedProx Round 29/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.8211
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9825
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9825
# 🌍 Global Holdout | Acc: 0.9832, Loss: 0.0687
# 💾 New BEST Model! Acc = 0.9832
#
# 🔁 [IID] FedProx Round 30/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9439
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9614
# 🌍 Global Holdout | Acc: 0.9794, Loss: 0.0701
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 31/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9719
# 🌍 Global Holdout | Acc: 0.9817, Loss: 0.0696
# ⏳ No improvement for 2/15 rounds
#
# 🔁 [IID] FedProx Round 32/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9789
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 2 | Train Acc: 0.9938, Local Test Acc: 0.9649
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9825
# 🌍 Global Holdout | Acc: 0.9764, Loss: 0.0875
# ⏳ No improvement for 3/15 rounds
#
# 🔁 [IID] FedProx Round 33/200
#   Client 0 | Train Acc: 0.9938, Local Test Acc: 0.9474
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9614
# 🌍 Global Holdout | Acc: 0.9725, Loss: 0.1155
# ⏳ No improvement for 4/15 rounds
#
# 🔁 [IID] FedProx Round 34/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9614
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9404
#   Client 2 | Train Acc: 0.9938, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9825
# 🌍 Global Holdout | Acc: 0.9779, Loss: 0.0770
# ⏳ No improvement for 5/15 rounds
#
# 🔁 [IID] FedProx Round 35/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9439
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9579
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9684
# 🌍 Global Holdout | Acc: 0.9855, Loss: 0.0639
# 💾 New BEST Model! Acc = 0.9855
#
# 🔁 [IID] FedProx Round 36/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 0.9969, Local Test Acc: 0.9193
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9439
# 🌍 Global Holdout | Acc: 0.9855, Loss: 0.0561
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 37/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9754
# 🌍 Global Holdout | Acc: 0.9840, Loss: 0.0673
# ⏳ No improvement for 2/15 rounds
#
# 🔁 [IID] FedProx Round 38/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9439
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9789
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9404
# 🌍 Global Holdout | Acc: 0.9825, Loss: 0.0664
# ⏳ No improvement for 3/15 rounds
#
# 🔁 [IID] FedProx Round 39/200
#   Client 0 | Train Acc: 0.9969, Local Test Acc: 0.9333
#   Client 1 | Train Acc: 0.9938, Local Test Acc: 0.9333
#   Client 2 | Train Acc: 0.9969, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9684
# 🌍 Global Holdout | Acc: 0.9817, Loss: 0.0863
# ⏳ No improvement for 4/15 rounds
#
# 🔁 [IID] FedProx Round 40/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 1 | Train Acc: 0.9906, Local Test Acc: 0.9684
#   Client 2 | Train Acc: 0.9969, Local Test Acc: 0.9684
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9544
# 🌍 Global Holdout | Acc: 0.9847, Loss: 0.0604
# ⏳ No improvement for 5/15 rounds
#
# 🔁 [IID] FedProx Round 41/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9368
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9614
# 🌍 Global Holdout | Acc: 0.9825, Loss: 0.0722
# ⏳ No improvement for 6/15 rounds
#
# 🔁 [IID] FedProx Round 42/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9368
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9754
# 🌍 Global Holdout | Acc: 0.9878, Loss: 0.0563
# 💾 New BEST Model! Acc = 0.9878
#
# 🔁 [IID] FedProx Round 43/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 0.9875, Local Test Acc: 0.9439
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9789
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9228
# 🌍 Global Holdout | Acc: 0.9687, Loss: 0.1379
# ⏳ No improvement for 1/15 rounds
#
# 🔁 [IID] FedProx Round 44/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 2 | Train Acc: 0.9969, Local Test Acc: 0.9088
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9474
# 🌍 Global Holdout | Acc: 0.9840, Loss: 0.0711
# ⏳ No improvement for 2/15 rounds
#
# 🔁 [IID] FedProx Round 45/200
#   Client 0 | Train Acc: 0.9969, Local Test Acc: 0.9368
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9544
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9825
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9840, Loss: 0.0578
# ⏳ No improvement for 3/15 rounds
#
# 🔁 [IID] FedProx Round 46/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9614
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9649
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9754
# 🌍 Global Holdout | Acc: 0.9855, Loss: 0.0613
# ⏳ No improvement for 4/15 rounds
#
# 🔁 [IID] FedProx Round 47/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9544
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9439
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9719
# 🌍 Global Holdout | Acc: 0.9840, Loss: 0.0599
# ⏳ No improvement for 5/15 rounds
#
# 🔁 [IID] FedProx Round 48/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9509
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9614
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9825, Loss: 0.0674
# ⏳ No improvement for 6/15 rounds
#
# 🔁 [IID] FedProx Round 49/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9789
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 3 | Train Acc: 0.9938, Local Test Acc: 0.9825
# 🌍 Global Holdout | Acc: 0.9809, Loss: 0.0809
# ⏳ No improvement for 7/15 rounds
#
# 🔁 [IID] FedProx Round 50/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9930
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9719
# 🌍 Global Holdout | Acc: 0.9840, Loss: 0.0644
# ⏳ No improvement for 8/15 rounds
#
# 🔁 [IID] FedProx Round 51/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9789
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.8772
# 🌍 Global Holdout | Acc: 0.9748, Loss: 0.1104
# ⏳ No improvement for 9/15 rounds
#
# 🔁 [IID] FedProx Round 52/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9544
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9895
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9764, Loss: 0.1015
# ⏳ No improvement for 10/15 rounds
#
# 🔁 [IID] FedProx Round 53/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9719
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9860
# 🌍 Global Holdout | Acc: 0.9809, Loss: 0.0710
# ⏳ No improvement for 11/15 rounds
#
# 🔁 [IID] FedProx Round 54/200
#   Client 0 | Train Acc: 0.9969, Local Test Acc: 0.9439
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9860
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9649
# 🌍 Global Holdout | Acc: 0.9855, Loss: 0.0636
# ⏳ No improvement for 12/15 rounds
#
# 🔁 [IID] FedProx Round 55/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9684
#   Client 1 | Train Acc: 0.9969, Local Test Acc: 0.9789
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9895
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9855, Loss: 0.0556
# ⏳ No improvement for 13/15 rounds
#
# 🔁 [IID] FedProx Round 56/200
#   Client 0 | Train Acc: 0.9969, Local Test Acc: 0.9263
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9895
#   Client 3 | Train Acc: 1.0000, Local Test Acc: 0.9754
# 🌍 Global Holdout | Acc: 0.9847, Loss: 0.0581
# ⏳ No improvement for 14/15 rounds
#
# 🔁 [IID] FedProx Round 57/200
#   Client 0 | Train Acc: 1.0000, Local Test Acc: 0.9649
#   Client 1 | Train Acc: 1.0000, Local Test Acc: 0.9754
#   Client 2 | Train Acc: 1.0000, Local Test Acc: 0.9719
#   Client 3 | Train Acc: 0.9969, Local Test Acc: 0.9789
# 🌍 Global Holdout | Acc: 0.9802, Loss: 0.0741
# ⏳ No improvement for 15/15 rounds
#
# 🛑 Early stopping triggered!
#
# ✅ Saved:
#    • best_fedprox_iid_pretrained.pth
#    • metrics_history_fedprox_iid_pretrained.npy

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# ============================================================
#      LOAD METRICS FROM FEDPROX PRETRAINED (IID RUN)
# ============================================================

rounds = metrics_history_fedprox_iid_pretrained["round"]
holdout_metrics = metrics_history_fedprox_iid_pretrained["holdout"]

accs = [m["acc"] for m in holdout_metrics]
losses = [m["loss"] for m in holdout_metrics]

# ============================================================
#                PLOT GLOBAL ACCURACY PER ROUND
# ============================================================

plt.figure(figsize=(7, 5))
plt.plot(rounds, accs, marker='o', linewidth=2)
plt.title("FedProx (IID Pretrained ResNet18) — Global Accuracy per Round")
plt.xlabel("Round")
plt.ylabel("Accuracy")
plt.grid(True)
plt.tight_layout()
plt.show()

# ============================================================
#                PLOT GLOBAL LOSS PER ROUND
# ============================================================

plt.figure(figsize=(7, 5))
plt.plot(rounds, losses, marker='o', color="red", linewidth=2)
plt.title("FedProx (IID Pretrained ResNet18) — Global Loss per Round")
plt.xlabel("Round")
plt.ylabel("Loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# ============================================================
#         SAVE ROUND/ACC/LOSS ARRAYS FOR COMPARISON
# ============================================================

np.save("fedprox_iid_pretrained_rounds.npy", np.array(rounds))
np.save("fedprox_iid_pretrained_acc.npy", np.array(accs))
np.save("fedprox_iid_pretrained_loss.npy", np.array(losses))

print("Saved: fedprox_iid_pretrained_rounds.npy, fedprox_iid_pretrained_acc.npy, fedprox_iid_pretrained_loss.npy")

# ============================================================
#         LOAD BEST FEDPROX PRETRAINED IID MODEL
# ============================================================

best_model_fedprox = create_pretrained_resnet18_fedprox(NUM_CLASSES)
best_model_fedprox.load_state_dict(torch.load("best_fedprox_iid_pretrained.pth"))
best_model_fedprox.to(DEVICE)
best_model_fedprox.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in holdout_loader:   # ← FedProx uses holdout_loader (not _iid)
        x = x.to(DEVICE)
        y = y.to(DEVICE)

        logits = best_model_fedprox(x)
        preds = logits.argmax(dim=1)

        all_preds.append(preds.cpu())
        all_labels.append(y.cpu())

all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

# ============================================================
#                  HOLDOUT METRIC COMPUTATION
# ============================================================

acc  = (all_preds == all_labels).mean()
prec = precision_score(all_labels, all_preds, average="macro")
rec  = recall_score(all_labels, all_preds, average="macro")
f1   = f1_score(all_labels, all_preds, average="macro")

print("\n📊 FEDPROX IID PRETRAINED — GLOBAL HOLDOUT METRICS")
print(f"Accuracy :  {acc:.4f}")
print(f"Precision:  {prec:.4f}")
print(f"Recall   :  {rec:.4f}")
print(f"F1-Score :  {f1:.4f}")

# ============================================================
#                  CONFUSION MATRIX
# ============================================================

cm = confusion_matrix(all_labels, all_preds)
class_names = train_dataset.classes

plt.figure(figsize=(8, 6))
sns.heatmap(cm,
            annot=True,
            fmt="d",
            cmap="Blues",
            xticklabels=class_names,
            yticklabels=class_names)
plt.title("Confusion Matrix — FedProx (IID Pretrained)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()

# ============================================================
#            SAVE CONFUSION MATRIX
# ============================================================

np.save("fedprox_iid_pretrained_confusion_matrix.npy", cm)
print("\nSaved confusion matrix → fedprox_iid_pretrained_confusion_matrix.npy")
# Out:
# Saved: fedprox_iid_pretrained_rounds.npy, fedprox_iid_pretrained_acc.npy, fedprox_iid_pretrained_loss.npy
#
# 📊 FEDPROX IID PRETRAINED — GLOBAL HOLDOUT METRICS
# Accuracy :  0.9878
# Precision:  0.9872
# Recall   :  0.9870
# F1-Score :  0.9871
# Saved confusion matrix → fedprox_iid_pretrained_confusion_matrix.npy

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    precision_score, recall_score, f1_score
)
import torch.nn as nn
from torchvision import models
import seaborn as sns


# ============================================================
# DEVICE SETUP
# ============================================================
DEVICE = torch.device("mps" if torch.backends.mps.is_available()
          else "cuda" if torch.cuda.is_available()
          else "cpu")
print("Using:", DEVICE)


# ============================================================
# MODEL REBUILDER (matches training architecture)
# ============================================================
def create_resnet18_pretrained_eval(num_classes):
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

    # Frozen layers (same as training)
    for p in model.conv1.parameters():  p.requires_grad = False
    for p in model.bn1.parameters():    p.requires_grad = False
    for p in model.layer1.parameters(): p.requires_grad = False
    for p in model.layer2.parameters(): p.requires_grad = False

    # Trainable layers (same as training)
    for p in model.layer3.parameters(): p.requires_grad = True
    for p in model.layer4.parameters(): p.requires_grad = True

    # Replace FC
    in_f = model.fc.in_features
    model.fc = nn.Linear(in_f, num_classes)

    return model


# ============================================================
# LOAD METRICS FOR FEDAVG AND FEDPROX
# ============================================================
fedavg_hist = np.load("metrics_history_fedavg_iid_pretrained.npy",
                      allow_pickle=True).item()

fedprox_hist = np.load("metrics_history_fedprox_iid_pretrained.npy",
                       allow_pickle=True).item()

# Extract rounds & curves
rounds_fa = fedavg_hist["round"]
rounds_fp = fedprox_hist["round"]

acc_fa  = [h["acc"] for h in fedavg_hist["holdout"]]
acc_fp  = [h["acc"] for h in fedprox_hist["holdout"]]

loss_fa = [h["loss"] for h in fedavg_hist["holdout"]]
loss_fp = [h["loss"] for h in fedprox_hist["holdout"]]


# ============================================================
# LOAD TRAINED MODELS
# ============================================================
fedavg_model = create_resnet18_pretrained_eval(NUM_CLASSES_IID).to(DEVICE)
fedavg_model.load_state_dict(torch.load("best_fedavg_iid_pretrained.pth",
                                        map_location=DEVICE))
fedavg_model.eval()

fedprox_model = create_resnet18_pretrained_eval(NUM_CLASSES_IID).to(DEVICE)
fedprox_model.load_state_dict(torch.load("best_fedprox_iid_pretrained.pth",
                                         map_location=DEVICE))
fedprox_model.eval()

criterion = nn.CrossEntropyLoss()


# ============================================================
# UNIFIED EVALUATION FUNCTION
# ============================================================
def evaluate_full(model, loader):
    model.eval()
    total_loss = 0
    total = 0
    preds_all = []
    labels_all = []

    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            logits = model(x)
            loss = criterion(logits, y)

            total_loss += loss.item() * x.size(0)
            total += x.size(0)

            preds = logits.argmax(dim=1)
            preds_all.append(preds.cpu())
            labels_all.append(y.cpu())

    preds_all = torch.cat(preds_all).numpy()
    labels_all = torch.cat(labels_all).numpy()

    return {
        "acc": (preds_all == labels_all).mean(),
        "loss": total_loss / total,
        "precision": precision_score(labels_all, preds_all, average="macro", zero_division=0),
        "recall": recall_score(labels_all, preds_all, average="macro", zero_division=0),
        "f1": f1_score(labels_all, preds_all, average="macro", zero_division=0),
        "preds": preds_all,
        "labels": labels_all
    }


# ============================================================
# RUN FINAL EVALUATION FOR BOTH METHODS
# ============================================================
fa_final = evaluate_full(fedavg_model, holdout_loader_iid)
fp_final = evaluate_full(fedprox_model, holdout_loader_iid)

print("\n====== FedAvg IID Results ======")
for k, v in fa_final.items():
    if k not in ("preds", "labels"):
        print(f"{k}: {v:.4f}")

print("\n====== FedProx IID Results ======")
for k, v in fp_final.items():
    if k not in ("preds", "labels"):
        print(f"{k}: {v:.4f}")


# ============================================================
# ACCURACY CURVE — FedAvg vs FedProx
# ============================================================
plt.figure(figsize=(10,5))
plt.plot(rounds_fa, acc_fa, marker='o', label="FedAvg Accuracy")
plt.plot(rounds_fp, acc_fp, marker='o', label="FedProx Accuracy")
plt.xlabel("Rounds")
plt.ylabel("Accuracy")
plt.title("Global Accuracy per Round — FedAvg vs FedProx (IID)")
plt.grid()
plt.legend()
plt.show()


# ============================================================
# LOSS CURVE — FedAvg vs FedProx
# ============================================================
plt.figure(figsize=(10,5))
plt.plot(rounds_fa, loss_fa, marker='o', label="FedAvg Loss")
plt.plot(rounds_fp, loss_fp, marker='o', label="FedProx Loss")
plt.xlabel("Rounds")
plt.ylabel("Loss")
plt.title("Global Loss per Round — FedAvg vs FedProx (IID)")
plt.grid()
plt.legend()
plt.show()


# ============================================================
# CONFUSION MATRICES — Side-by-Side
# ============================================================
cm_fa = confusion_matrix(fa_final["labels"], fa_final["preds"])
cm_fp = confusion_matrix(fp_final["labels"], fp_final["preds"])

fig, ax = plt.subplots(1, 2, figsize=(14,6))

ConfusionMatrixDisplay(cm_fa).plot(ax=ax[0], cmap="Blues")
ConfusionMatrixDisplay(cm_fp).plot(ax=ax[1], cmap="Purples")

ax[0].set_title("FedAvg IID — Confusion Matrix")
ax[1].set_title("FedProx IID — Confusion Matrix")

plt.tight_layout()
plt.show()


# ============================================================
# BAR PLOT — Accuracy, Precision, Recall, F1 (Comparison)
# ============================================================
labels = ["Accuracy", "Precision", "Recall", "F1 Score"]
fa_vals = [fa_final["acc"], fa_final["precision"], fa_final["recall"], fa_final["f1"]]
fp_vals = [fp_final["acc"], fp_final["precision"], fp_final["recall"], fp_final["f1"]]

x = np.arange(len(labels))
w = 0.35

plt.figure(figsize=(8,5))
plt.bar(x - w/2, fa_vals, w, label="FedAvg")
plt.bar(x + w/2, fp_vals, w, label="FedProx")
plt.xticks(x, labels)
plt.ylabel("Score")
plt.title("FedAvg vs FedProx — Performance Comparison (IID)")
plt.legend()
plt.grid(alpha=0.2)
plt.show()
# Out:
# Using: mps
#
# ====== FedAvg IID Results ======
# acc: 0.9855
# loss: 0.0582
# precision: 0.9845
# recall: 0.9843
# f1: 0.9844
#
# ====== FedProx IID Results ======
# acc: 0.9878
# loss: 0.0563
# precision: 0.9872
# recall: 0.9870
# f1: 0.9871
